# %%
import json
from collections import defaultdict

# 读取两个JSON文件
with open('static/space_results.json', 'r', encoding='utf-8') as f:
    space_data = json.load(f)
with open('static/catering_results.json', 'r', encoding='utf-8') as f:
    catering_data = json.load(f)

# 提取财务分析数据
space_bars = space_data["财务数据"]["财务分析_bar"]
catering_bars = catering_data["财务分析"]["财务分析_bar"]

# 使用字典按周存储销售收入数据
combined_data = defaultdict(dict)

# %%
# 处理 space 数据
for item in space_bars:
    week = item["周"]
    combined_data[week]["周"] = week
    combined_data[week]["场景收入"] = item["销售收入"]

# 处理 catering 数据并合并
for item in catering_bars:
    week = item["订单周"]
    combined_data[week]["周"] = week
    combined_data[week]["餐饮收入"] = item["销售收入"]

# 转换为列表并按周排序
result = []
for week in combined_data:
    week_data = {
        "周": combined_data[week]["周"],
        "场景收入": combined_data[week].get("场景收入", 0.0),
        "餐饮收入": combined_data[week].get("餐饮收入", 0.0)
    }
    result.append(week_data)
result.sort(key=lambda x: x["周"])

# %%
# 计算wow和mom，创建单独的trailing_4_week数据结构
trailing_data = []
for i in range(len(result)):
    # 计算trailing 4 week收入
    space_trailing_4 = sum(d["场景收入"] for d in result[max(0, i-3):i+1])
    catering_trailing_4 = sum(d["餐饮收入"] for d in result[max(0, i-3):i+1])
    
    week_trailing = {
        "周": result[i]["周"],
        "场景_trailing_4_week收入": space_trailing_4,
        "餐饮_trailing_4_week收入": catering_trailing_4
    }
    
    # 计算wow（与上周相比）
    if i > 0:
        prev_space = trailing_data[i-1]["场景_trailing_4_week收入"]
        prev_catering = trailing_data[i-1]["餐饮_trailing_4_week收入"]
        
        week_trailing["场景_wow"] = (space_trailing_4 / prev_space - 1) if prev_space != 0 else 0
        week_trailing["餐饮_wow"] = (catering_trailing_4 / prev_catering - 1) if prev_catering != 0 else 0
    else:
        week_trailing["场景_wow"] = 0
        week_trailing["餐饮_wow"] = 0
    
    # 计算mom（与4周前相比）
    if i >= 4:
        prev_4_space = trailing_data[i-4]["场景_trailing_4_week收入"]
        prev_4_catering = trailing_data[i-4]["餐饮_trailing_4_week收入"]
        
        week_trailing["场景_mom"] = (space_trailing_4 / prev_4_space - 1) if prev_4_space != 0 else 0
        week_trailing["餐饮_mom"] = (catering_trailing_4 / prev_4_catering - 1) if prev_4_catering != 0 else 0
    else:
        week_trailing["场景_mom"] = 0
        week_trailing["餐饮_mom"] = 0
    
    trailing_data.append(week_trailing)

# %%
# 创建wow_result和mom_result
wow_result = [{
    "周": week["周"],
    "场景周环比": week["场景_wow"],
    "餐饮周环比": week["餐饮_wow"]
} for week in trailing_data]

mom_result = [{
    "周": week["周"],
    "场景月环比": week["场景_mom"],
    "餐饮月环比": week["餐饮_mom"]
} for week in trailing_data]

# 构建输出结构
output_data = {
    "销售收入_stacked": result,
    "过去四周收入周环比_line": wow_result,
    "过去四周收入月环比_line": mom_result
}

# %%
print (output_data)
# Out:
# {'销售收入_stacked': [{'周': '2023-09-05', '场景收入': 0.0, '餐饮收入': 0.0}, {'周': '2023-09-12', '场景收入': 0.0, '餐饮收入': 0.0}, {'周': '2023-09-19', '场景收入': 0.0, '餐饮收入': 9197.0}, {'周': '2023-09-26', '场景收入': 0.0, '餐饮收入': 18480.6}, {'周': '2023-10-03', '场景收入': 0.0, '餐饮收入': 20357.1}, {'周': '2023-10-10', '场景收入': 0.0, '餐饮收入': 32687.2}, {'周': '2023-10-17', '场景收入': 0.0, '餐饮收入': 49783.0}, {'周': '2023-10-24', '场景收入': 0.0, '餐饮收入': 26717.3}, {'周': '2023-10-31', '场景收入': 0.0, '餐饮收入': 27931.1}, {'周': '2023-11-07', '场景收入': 0.0, '餐饮收入': 30085.8}, {'周': '2023-11-14', '场景收入': 0.0, '餐饮收入': 27599.23}, {'周': '2023-11-21', '场景收入': 0.0, '餐饮收入': 28647.45}, {'周': '2023-11-28', '场景收入': 0.0, '餐饮收入': 27453.6}, {'周': '2023-12-05', '场景收入': 881.0, '餐饮收入': 22323.4}, {'周': '2023-12-12', '场景收入': 803.0, '餐饮收入': 21163.35}, {'周': '2023-12-19', '场景收入': 795.0, '餐饮收入': 27244.1}, {'周': '2023-12-26', '场景收入': 103.0, '餐饮收入': 17074.22}, {'周': '2024-01-02', '场景收入': 1277.0, '餐饮收入': 14732.48}, {'周': '2024-01-09', '场景收入': 973.2, '餐饮收入': 18140.3}, {'周': '2024-01-16', '场景收入': 184.0, '餐饮收入': 22286.66}, {'周': '2024-01-23', '场景收入': 1173.0, '餐饮收入': 24370.28}, {'周': '2024-01-30', '场景收入': 928.0, '餐饮收入': 11898.12}, {'周': '2024-02-06', '场景收入': 0.0, '餐饮收入': 6634.96}, {'周': '2024-02-13', '场景收入': 368.0, '餐饮收入': 18855.96}, {'周': '2024-02-20', '场景收入': 0.0, '餐饮收入': 12335.84}, {'周': '2024-02-27', '场景收入': 0.0, '餐饮收入': 24839.0}, {'周': '2024-03-05', '场景收入': 240.0, '餐饮收入': 26698.21}, {'周': '2024-03-12', '场景收入': 0.0, '餐饮收入': 31970.84}, {'周': '2024-03-19', '场景收入': 10451.0, '餐饮收入': 80649.03}, {'周': '2024-03-26', '场景收入': 7659.75, '餐饮收入': 31801.84}, {'周': '2024-04-02', '场景收入': 7174.0, '餐饮收入': 23338.8}, {'周': '2024-04-09', '场景收入': 9947.67, '餐饮收入': 27425.57}, {'周': '2024-04-16', '场景收入': 9002.35, '餐饮收入': 27894.16}, {'周': '2024-04-23', '场景收入': 7563.65, '餐饮收入': 34863.92}, {'周': '2024-04-30', '场景收入': 9586.75, '餐饮收入': 42986.42}, {'周': '2024-05-07', '场景收入': 8431.5, '餐饮收入': 28896.82}, {'周': '2024-05-14', '场景收入': 9074.13, '餐饮收入': 34899.52}, {'周': '2024-05-21', '场景收入': 13555.85, '餐饮收入': 35061.11}, {'周': '2024-05-28', '场景收入': 8513.1, '餐饮收入': 29229.19}, {'周': '2024-06-04', '场景收入': 9330.45, '餐饮收入': 44251.299999999996}, {'周': '2024-06-11', '场景收入': 8238.31, '餐饮收入': 36722.01}, {'周': '2024-06-18', '场景收入': 9745.11, '餐饮收入': 29428.26}, {'周': '2024-06-25', '场景收入': 8872.0, '餐饮收入': 27716.3}, {'周': '2024-07-02', '场景收入': 13980.15, '餐饮收入': 29705.45}, {'周': '2024-07-09', '场景收入': 12053.84, '餐饮收入': 31911.28}, {'周': '2024-07-16', '场景收入': 14422.85, '餐饮收入': 29661.8}, {'周': '2024-07-23', '场景收入': 13635.35, '餐饮收入': 28406.08}, {'周': '2024-07-30', '场景收入': 11862.880000000001, '餐饮收入': 30850.01}, {'周': '2024-08-06', '场景收入': 11444.83, '餐饮收入': 26615.82}, {'周': '2024-08-13', '场景收入': 12219.35, '餐饮收入': 24236.53}, {'周': '2024-08-20', '场景收入': 11025.55, '餐饮收入': 28320.82}, {'周': '2024-08-27', '场景收入': 11478.38, '餐饮收入': 28506.2}, {'周': '2024-09-03', '场景收入': 12384.23, '餐饮收入': 29244.76}, {'周': '2024-09-10', '场景收入': 10223.51, '餐饮收入': 24819.21}, {'周': '2024-09-17', '场景收入': 11692.2, '餐饮收入': 29728.68}, {'周': '2024-09-24', '场景收入': 9346.7, '餐饮收入': 33260.12}, {'周': '2024-10-01', '场景收入': 12244.25, '餐饮收入': 37143.47}, {'周': '2024-10-08', '场景收入': 18619.13, '餐饮收入': 39928.0}, {'周': '2024-10-15', '场景收入': 19012.5, '餐饮收入': 37069.88}, {'周': '2024-10-22', '场景收入': 10641.0, '餐饮收入': 32033.55}, {'周': '2024-10-29', '场景收入': 12664.38, '餐饮收入': 38924.44}, {'周': '2024-11-05', '场景收入': 9820.75, '餐饮收入': 45090.28}, {'周': '2024-11-12', '场景收入': 10976.06, '餐饮收入': 33446.37}, {'周': '2024-11-19', '场景收入': 12149.0, '餐饮收入': 29612.44}, {'周': '2024-11-26', '场景收入': 17722.85, '餐饮收入': 34542.21}, {'周': '2024-12-03', '场景收入': 17353.7, '餐饮收入': 37733.78}, {'周': '2024-12-10', '场景收入': 18927.0, '餐饮收入': 35510.24}, {'周': '2024-12-17', '场景收入': 22900.5, '餐饮收入': 40595.23}, {'周': '2024-12-24', '场景收入': 15757.25, '餐饮收入': 34140.44}, {'周': '2024-12-31', '场景收入': 18031.53, '餐饮收入': 36243.06}, {'周': '2025-01-07', '场景收入': 15639.5, '餐饮收入': 89705.9}, {'周': '2025-01-14', '场景收入': 13167.0, '餐饮收入': 23721.07}, {'周': '2025-01-21', '场景收入': 9192.35 ...
